# %%
import pandas as pd
from pathlib import Path
pd.set_option("display.max_columns", 200)

pd.options.mode.copy_on_write = True

# %%
# Read in the Active Grant csv and store into Pandas DataFrame
# https://data.hrsa.gov//DataDownload/DD_Files/EHB_ACTIVE_GRANT_FA_AGR.csv (source file)
ehb_award_path = Path("data/FS_EHB_AWARD_GRANT_FA_AGR_MVX.csv")
ehb_award_df = pd.read_csv(ehb_award_path, encoding="utf-8")

ehb_award_df.head(2)
# Out:
# C:\Users\leeba\AppData\Local\Temp\ipykernel_10096\272605760.py:4: DtypeWarning: Columns (24,25,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   ehb_award_df = pd.read_csv(ehb_award_path, encoding="utf-8")
#    Award Year  Financial Assistance            Grantee Address  Grantee City  \
# 0        2018               96750.0  1920 Columbia Dr SE Ste B   Albuquerque
# 1        2018             1387501.0                  4471 NM-4  Jemez Pueblo
#
#   Grantee County Description Grantee County Name  \
# 0         County                      Bernalillo
# 1         County                        Sandoval
#
#                                 Grantee Name  Grantee Region Code HRSA Region  \
# 0  PARENTS REACHING OUT TO HELP INCORPORATED                  6.0    Region 6
# 1                            Pueblo of Jemez                  6.0    Region 6
#
#   Grantee State Abbreviation  State Name Grantee ZIP Code Grant Activity Code  \
# 0                         NM  New Mexico       87106-3307                 H84
# 1                         NM  New Mexico            87024                 H80
#
#   Grant Number  Grant Serial Number Project Period Start Date  \
# 0   H84MC08007                 8007                06/01/2007
# 1   H80CS26584                26584                11/01/2013
#
#   Project Period Start Date Text String Grant Project Period End Date  \
# 0                            2007/06/01                    05/31/2022
# 1                            2013/11/01                    02/28/2019
#
#   Grant Project Period End Date Text HRSA Program Area Code  \
# 0                         2022/05/31                   MCHB
# 1                         2019/02/28                   BPHC
#
#       HRSA Program Area Name Complete County Name  \
# 0  Maternal and Child Health    Bernalillo County
# 1        Primary Health Care      Sandoval County
#
#                             Grant Program Name Congressional District Name  \
# 0  Family Professional Partnership/CSHCN (H84)      New Mexico District 01
# 1                  Health Center Program (H80)      New Mexico District 03
#
#   Congressional District Number HHS Region Number  \
# 0                            01                 6
# 1                            03                 6
#
#   U.S. Congressional Representative Name  \
# 0                 Michelle Lujan Grisham
# 1                          Ben Ray Luján
#
#   State and County Federal Information Processing Standard Code  \
# 0                                              35001
# 1                                              35043
#
#   State FIPS Code U.S. - Mexico Border 100 Kilometer Indicator  \
# 0              35                                            N
# 1              35                                            N
#
#   U.S. - Mexico Border County Indicator Name of U.S. Senator Number One  \
# 0                                     N                 Martin Heinrich
# 1                                     N                 Martin Heinrich
#
#   Name of U.S. Senator Number Two  \
# 0                       Tom Udall
# 1                       Tom Udall
#
#        Uniform Data System Grant Program Description Abstract  \
# 0  This notice announces the opportunity to apply...  No Link
# 1  This notice announces the opportunity to apply...  No Link
#
#                Grantee Type Description DUNS Number Unique Entity Identifier  \
# 0  Corporate Entity, Federal Tax Exempt   168660009             K5HNRLKAV3M6
# 1                                 Other   119699460             VPNNXLA8QKV6
#
#         CCN  Geocoding Artifact Address Primary X Coordinate  \
# 0       NaN                                      -106.616077
# 1  321910.0                                      -106.729865
#
#    Geocoding Artifact Address Primary Y Coordinate  \
# 0                                        35.060327
# 1                                        35.600742
#
#   Data Warehouse Record Create Date Data Warehouse Record Create Date Text  \
# 0                        11/30/2018                             2018/11/30
# 1                        11/30/2018                             2018/11/30
#
#    Unnamed: 43
# 0          NaN
# 1          NaN

# %%
# isolate 2023 data
ehb_award_2023_df = ehb_award_df[(ehb_award_df['Award Year'] == 2023)]

ehb_award_2023_df.head(2)
# Out:
#      Award Year  Financial Assistance      Grantee Address Grantee City  \
# 236        2023              299997.0        1000 E 5th St   Greenville
# 237        2023              299998.0  121 University Hall     Columbia
#
#     Grantee County Description Grantee County Name  \
# 236         County                            Pitt
# 237         County                           Boone
#
#                       Grantee Name  Grantee Region Code HRSA Region  \
# 236       EAST CAROLINA UNIVERSITY                  4.0    Region 4
# 237  UNIVERSITY OF MISSOURI SYSTEM                  7.0    Region 7
#
#     Grantee State Abbreviation      State Name Grantee ZIP Code  \
# 236                         NC  North Carolina       27858-2502
# 237                         MO        Missouri       65211-3020
#
#     Grant Activity Code Grant Number  Grant Serial Number  \
# 236                 H2A   H2ARH39979                39979
# 237                 H2A   H2ARH39974                39974
#
#     Project Period Start Date Project Period Start Date Text String  \
# 236                09/01/2020                            2020/09/01
# 237                09/01/2020                            2020/09/01
#
#     Grant Project Period End Date Grant Project Period End Date Text  \
# 236                    08/31/2024                         2024/08/31
# 237                    08/31/2024                         2024/08/31
#
#     HRSA Program Area Code HRSA Program Area Name Complete County Name  \
# 236                    OAT            Tele-Health          Pitt County
# 237                    OAT            Tele-Health         Boone County
#
#                          Grant Program Name Congressional District Name  \
# 236  Telehealth Network Grant Program (H2A)  North Carolina District 01
# 237  Telehealth Network Grant Program (H2A)        Missouri District 03
#
#     Congressional District Number HHS Region Number  \
# 236                            01                 4
# 237                            03                 7
#
#     U.S. Congressional Representative Name  \
# 236                        Donald G. Davis
# 237                     Blaine Luetkemeyer
#
#     State and County Federal Information Processing Standard Code  \
# 236                                              37147
# 237                                              29019
#
#     State FIPS Code U.S. - Mexico Border 100 Kilometer Indicator  \
# 236              37                                            N
# 237              29                                            N
#
#     U.S. - Mexico Border County Indicator Name of U.S. Senator Number One  \
# 236                                     N                     Thom Tillis
# 237                                     N                     Josh Hawley
#
#     Name of U.S. Senator Number Two  \
# 236                     Thom Tillis
# 237                     Josh Hawley
#
#     Uniform Data System Grant Program Description Abstract  \
# 236                                           NaN  No Link
# 237                                           NaN  No Link
#
#     Grantee Type Description DUNS Number Unique Entity Identifier  CCN  \
# 236                    Other   607579018             HWPEKM8VFTJ9  NaN
# 237                    Other   153890272             SZPJL5ZRCLF4  NaN
#
#      Geocoding Artifact Address Primary X Coordinate  \
# 236                                       -77.361682
# 237                                       -92.343038
#
#      Geocoding Artifact Address Primary Y Coordinate  \
# 236                                        35.607112
# 237                                        38.937355
#
#     Data Warehouse Record Create Date Data Warehouse Record Create Date Text  \
# 236                        10/13/2023                             2023/10/13
# 237                        10/13/2023                             2023/10/13
#
#      Unnamed: 43
# 236          NaN
# 237          NaN

# %%
# Number of unique grant programs
len(ehb_award_df['Grant Program Name'].unique())
# Out:
# 497

# %%
# look at how the naming is formated
names = ehb_award_df[(ehb_award_df['HRSA Program Area Name'] == 'Maternal and Child Health')]
names['Grant Program Name'].unique()
# Out:
# array(['Family Professional Partnership/CSHCN (H84)',
#        'Leadership Education in Neurodevelopmental and Related Disorders Training Program (T73)',
#        'Training CED/COR Pediatric and Child Psychiatry (T20)',
#        "Children's Oral Healthcare Access Program (H47)",
#        'MCH Autism Longitudinal Data Project (UJ2)',
#        'Integrated Community Systems for CSHCN (D70)',
#        'Awareness and Access to Care for Children and Youth with Epilepsy (H98)',
#        'Maternal and Child Health Public Health Training Program (T76)',
#        'Partnership for MCH Leadership Community (U01)',
#        'Healthy Tomorrows Partnership for Children Program (H17)',
#        'Maternal and Child Health Field-Initiated Research Program (R40)',
#        'Infant-Toddler Court Program (U2Z)',
#        'Early Childhood Comprehensive Systems: Health Integration Prenatal to Three Program (U7E)',
#        'EMSC Targeted Issue Grants (H34)',
#        'Universal Newborn Hearing Screening and Intervention (H61)',
#        'Healthy Start Initiative-Eliminating Racial/Ethnic Disparities (H49)',
#        'Hemophilia Treatment Centers (SPRANS) (H30)',
#        'EMSC Partnership Grants (H33)',
#        'Maternal, Infant and Early Childhood Homevisiting Grant Program (X10)',
#        'MCH Research Network Programs (UA6)',
#        'MCH Advanced Education Policy (U02)', 'Thalassemia (U1A)',
#        'Sickle Cell Disease Newborn Screening Follow-up Program (D1J)',
#        'Leadership Education  in Adolescent Health (LEAH) (T71)',
#        'Pediatric Emergency Care Applied Research Network (PECARN) (U03)',
#        'National Maternal and Child Health Data Resource Center (U59)',
#        'Autism Intervention Research Networks (UA3)',
#        'Developmental-Behavioral Pediatrics Training Program (T77)',
#        'National Emergency Medical Services for Children (EMSC) Resource Centers Demonstration CA (U07)',
#        'Regional Genetics Networks (UH7)',
#        'MCH Pipeline Training Program (T16)',
#        'Community-Based Integrated Service Systems (Local/State) (H25)',
#        'Traumatic Brain Injury Implementation (H21)',
#        'Maternal and Child Health Nutrition Training Program (T79)',
#        'National Organizations for State and Local Officials (UD3)',
#        'American Rescue Plan Act Funding for Home Visiting (X11)',
#        'Traumatic Brain Injury Protection and Advocacy (X82)',
#        'State Adolescent and Young Adult Health Capacity Building Program (U45)',
#        'Epidemiological MCH/SPH Institute (T03)',
#        'Reaching Practicing MCH Professionals in Underserved Areas Through Education and Training Program (T04)',
#        'State Implementation Grants for Improving Services for Children and Youth with ASD (H6M)',
#        'Newborn Screening Clearinghouse (U36)',
#        'Sickle Cell Treatment Demonstration Program (U1E)',
#        'Genetic Services Project (H46)',
#        'Leadership Training in Social Work (T19)',
#        'Pediatric Obesity CoIIN 2.0 (U7N)',
#        'Early Childhood Comprehensive Systems (UH3)',
#        'Pediatric Pulmonary Centers (T72)',
#        'Collaborative Improvement and Innovation Network on School-Based Health Services (U61)',
#        'Family/Professional Partnership/ CSHCN (U40)',
#        'Vision Screening in Young Children (H7M)',
#        'Fetal Alcohol Spectrum Disorders (U1H)',
#        'MCHB State Systems Development Initiative (H18)',
#        'Pediatric Mental Health Care Access Program (U4C)',
#        'Thalassemia (H87)',
#        'National Fetal and Infant Mortality Review (FIMR) Resource Center (U08)',
#        'Medical Home Capacity Building for CSHCN (U43)',
#        'Maternal and Child Health Services (B04)',
#        'Pediatric Mental Health Care Access Expansion (U4J)',
#        'Partnership for State Leadership Coop. Agreement- State Public Health Coordinating Center for Autism (UJ0)',
#        'Centers of Excellence in MCH Education, Science and Practice Program (T76)',
#        'State Maternal Health Innovation Program (U7A)',
#        'Early Childhood Comprehensive Systems Impact (H25)',
#        'Maternal and Child Health Public Health Catalyst Program (T1C)',
#        'MCH Knowledge to Practice (T21)',
#        'Bright Futures Pediatric Implementation (U04)',
#        'Disparities in Perinatal Health-Border Initiatives (H67)',
#        'Newborn Screening State Evaluation Program (E16)',
#        'State Newborn Screening Interoperability Planning Program (U2X)',
#        'National Genetics Education and Family Support Center (UH8)',
#        'National Coordinating Center (NCC) for the Regional Genetic Networks (UH9)',
#        'Autism Secondary Data Analysis Research (SDAR) Program (R41)',
#        'Family Leadership in Language and Learning (UJ1)',
#        'Training and Technical Assistance National Cooperative Agreements (NCAs) (U30)',
#        'Pediatric Research Network Program (U5D)', 'Oral Health (U44)',
#        'Child and Adolescent Injury and Violence Prevention Resource Centers Cooperative Agreement (U49)',
#        'Supporting Fetal Alcohol Spectrum Disorders (FASD) Screening and Intervention (UT9)',
#        'Autism Intervention Research Network on Physical Health (UT2)',
#        'Autism Intervention Research Network on Behavioral Health (UT3)',
#        'Autism CARES Act National Interdisciplinary Training Resource Center (UA5)',
#        'National Forum for State and Territorial Chief Executives (U98)',
#        'Alliance for Innovation on Maternal Health (UC4)',
#        'Comprehensive Hemophilia Diagnostic and Treatment Centers (UC8)',
#        'Home Visiting Research and Development Platform (UD5)',
#        'Home Visiting Collaborative Improvement and Innovation Network (UF4)',
#        'Supporting Healthy Start Performance Project (UF5)',
#        'MCH Workforce Centers (UE7)', 'MCH Navigator Program (UE8)',
#        'Safe Infant Sleep Systems Integration (SISSI) Program (UF7)',
#        'Maternal and Child Environmental Health Network (UG4)',
#        'National Fetal, Infant and Child Death Review Center Program (UG7)',
#        'Improving Timeliness of Newborn Screening Diagnosis (UG8)',
#        'Bright Futures for Women’s Health: Standard Practice Guidelines for Well Woman Care (UH0)',
#        'Innovations in Newborn Screening Interoperability (U2Y)',
#        'Measurement Research Network (U3D)', 'Sickle Cell (U38)',
#        'Pregnancy Related Research Network (U4D)',
#        'Alliance for Innovation on Maternal Health (AIM)- Community Care Initiative (U7B)',
#        'State Maternal Health Innovation Support and Implementation Program (U7C)',
#        'Severe Combined Immunodeficiency (SCID) Screening and Education (SC1)',
#        'Building Systems of Services for Children and Youth with Special Health Care Needs (U1T)',
#        'Supporting Maternal and Child Health Innovation in States (U1X)',
#        'Heritable Disorders (U22)',
#        'Awareness and Access to Care for Children and Youth with Epilepsy (U23)',
#        'Infant-Toddler Court Program (U2D)',
#        'Screening and Treatment for Maternal Depression and Related Behavioral Disorders Program (UK3)',
#        'Rural Integration Models for Parents and Children to Thrive:  A Two-Generational Approach to Strengt (UK4)',
#        'Newborn Screening Family Education Program (UK5)',
#        'American Rescue Plan Act – Pediatric Mental Health Care Access New Area Expansion (U4A)',
#        'Early Childhood Health Promotion System for High Need Program (UK2)',
#        'Maternal, Infant, and Early Childhood Home Visiting Program – Non-Profit (UG1)',
#        'Regional Pediatric Pandemic Network (U1I)',
#        'EMSC Data Center (UJ5)',
#        'Maternal and Child Health Telehealth Capacity for Public Health Systems (H7D)',
#        'Supporting Providers and Families to Access Telehealth and Distant Care Services for Maternal Health (H7E)',
#        'Health Care Delivery System Innovations for Children with Medical Complexity (UJ6)',
#        'Maternal, Infant and Early Childhood Home Visiting Program: Nonprofit Orgs (D90)',
#        'Bridging the Word Gap Research Network (U6D)',
#        'Rural Maternity and Obstetrics Management Strategies Program (UK9)',
#        'Networks for Oral Health Integration within the Maternal and Child Health Safety Net (UK7)',
#        'MCH Research Network on Promoting Healthy Weight (HW-RN) among Children with ASD and other DD (UT4)',
#        'Developmental-Behavioral Pediatrics Research Network (UT5)',
#        'MCH Leadership, Education, and Advancement in Undergraduate Pathways Program (T16)',
#        'Long-term Follow-up for SCID and other NBS Conditions (U1W)',
#        'Screening and Interventions for Adverse Childhood Experiences in Primary Care Settings Demonstration (U2C)',
#        'Emerging Issues in MCH (G31)',
#        'Catalysts for Infant Health Equity (U1V)',
#        'Enhancing Systems of Care for Children with Medical Complexity (UM2)',
#        'Transforming Pediatrics for Early Childhood (U9H)',
#        'Pediatric Mental Health Care Access - American Academy of Pediatrics (U4M)',
#        'Pediatric Mental Health Care Access - EMSC Innovation and Improvement Center (U4L)',
#        'R42 MCH Secondary Data Analysis Research (R42)',
#        'Universal Newborn Hearing Screening - Cooperative Agreement (U52)',
#        'MCH Adolescent and Young Adult Health Research Network (U8D)',
#        'Pediatric Mental Health Care Access - School Based Health Alliance (U4K)',
#        'Autism Transitions Research Project (UT6)',
#        'Sudden Unexpected Infant Death Prevention Program (UF7)',
#        'Autism Longitudinal Data Project (UT7)',
#        'Hereditary Hemorrhagic Telangiectasia (HHT) Program (UP4)',
#        'Alliance for Innovation on Maternal Health State Capacity Program (A30)',
#        'Poison Control Stabilization and Enhancement Program (H4B)',
#        'State Newborn Screening System Priorities Program (H4N)',
#        'Maternal Health Research Network (MH-RN) for MSIs--Research Awards (UR6)',
#        'Autism Secondary Data Analysis Program (R43)',
#        'Life Course Translational Research Network (U9D)',
#        'Children’s Healthy Weight State Capacity Building Program (U7N)',
#        'Comprehensive Systems Integration for Adolescent and Young Adult Health (U4N)',
#        'Integrated Maternal Health Services (U2E)',
#        'Institute for Home Visiting Workforce Development and Jackie Walorski Center for Evidence-Based Case (UU6)',
#        'Maternal Health Research Network for Minority-Serving Institutions (UR5)',
#        'Cooperative Newborn Screening System Priorities Program (UC1)',
#        'Alliance for Innovation on Maternal Health (AIM) Capacity (A30)',
#        'Transition for Youth with Autism and/or Epilepsy Demonstration Projects (H9E)',
#        'HRSA-24-041: National Coordinating Center on Transition (NCCT) (U2L)',
#        'Center for Maternal and Child Health Medicaid Partnerships (US8)',
#        'Child Care (U46)',
#        'Severe Combined Immunodeficiency (SCID) Newborn Screening Implementation Program (UG5)',
#        'EMSC Demonstration Grants (H3A)',
#        'Alliance for Innovation on Maternal and Child Health (UC4)',
#        'Providing support for the Collabortive Improvement and Innovation Network (CoIIN) to Reduce Infant M (UF3)',
#        'Leadership Education and Research Nursing (T80)',
#        'Autism Field-Initiated Innovative Research Studies Program (R41)',
#        'Maternal and Child Environmental Health Collaborative Improvement and Innovation Network (CoIIN) (UJ9)',
#        'Supporting Providers and Families to Access Telehealth and Distant Care Services for Pediatric Care (H7A)',
#        'Maternal, Infant, and Early Childhood Home Visiting (MIECHV) Research Program (R62)',
#        'Telehealth for Family Engagement (H7B)',
#        'Demonstration projects for integrating newborn screening long term follow-up into primary care pract (D93)',
#        'Healthy Behaviors in Women (H59)',
#        'MCH Community Integrated Service Systems Set-Aside Grant Program (H24)',
#        'Follow up in Newborn Screening (UG9)',
#        'Reproductive and Environmental Health Network (UG4)',
#        'Maternal, Infant and Early Childhood Home Visiting Program (D89)',
#        'Maternal, Infant, and Early Childhood Home Visiting Research Network (UD5)',
#        'Maternal, Infant and Early Childhood Home Visiting Program (X02)',
#        'Genetics in Primary Care (UC7)',
#        'Combating Autism Act Initiative (CAAI) National Interdisciplinary Training Resource Center (UA5)',
#        'Health Insurance and Financing/ CSHCN (U41)',
#        'Transition Services in Adolescent Health  - Healthy and Ready to Work (U39)',
#        'Sudden Infant Death Syndrome (U48)',
#        'Healthy Tomorrows Cooperative Agreement (U50)',
#        'Integrated Community Service Systems /CSHCN  (U42)',
#        'Healthy Start Leadership Training Institute (G23)'], dtype=object)

# %%
# create condensed df
code_for_program_df =names[['Grant Activity Code', 'Grant Program Name', 'HRSA Program Area Name']]

code_for_program_df
# Out:
#       Grant Activity Code                                 Grant Program Name  \
# 0                     H84        Family Professional Partnership/CSHCN (H84)
# 10                    H84        Family Professional Partnership/CSHCN (H84)
# 22                    T73  Leadership Education in Neurodevelopmental and...
# 27                    T73  Leadership Education in Neurodevelopmental and...
# 28                    T73  Leadership Education in Neurodevelopmental and...
# ...                   ...                                                ...
# 80548                 T04  Reaching Practicing MCH Professionals in Under...
# 80553                 T04  Reaching Practicing MCH Professionals in Under...
# 80557                 D70       Integrated Community Systems for CSHCN (D70)
# 80571                 U03  Pediatric Emergency Care Applied Research Netw...
# 80574                 T04  Reaching Practicing MCH Professionals in Under...
#
#           HRSA Program Area Name
# 0      Maternal and Child Health
# 10     Maternal and Child Health
# 22     Maternal and Child Health
# 27     Maternal and Child Health
# 28     Maternal and Child Health
# ...                          ...
# 80548  Maternal and Child Health
# 80553  Maternal and Child Health
# 80557  Maternal and Child Health
# 80571  Maternal and Child Health
# 80574  Maternal and Child Health
#
# [10978 rows x 3 columns]

# %%
# Remove duplicates from column 'Grant Activity Code'
code_for_program_df = code_for_program_df.drop_duplicates(subset = 'Grant Activity Code')

code_for_program_df
# Out:
#       Grant Activity Code                                 Grant Program Name  \
# 0                     H84        Family Professional Partnership/CSHCN (H84)
# 22                    T73  Leadership Education in Neurodevelopmental and...
# 30                    T20  Training CED/COR Pediatric and Child Psychiatr...
# 54                    H47    Children's Oral Healthcare Access Program (H47)
# 58                    UJ2         MCH Autism Longitudinal Data Project (UJ2)
# ...                   ...                                                ...
# 69102                 U39  Transition Services in Adolescent Health  - He...
# 73971                 U48                 Sudden Infant Death Syndrome (U48)
# 74523                 U50      Healthy Tomorrows Cooperative Agreement (U50)
# 77118                 U42  Integrated Community Service Systems /CSHCN  (...
# 78598                 G23  Healthy Start Leadership Training Institute (G23)
#
#           HRSA Program Area Name
# 0      Maternal and Child Health
# 22     Maternal and Child Health
# 30     Maternal and Child Health
# 54     Maternal and Child Health
# 58     Maternal and Child Health
# ...                          ...
# 69102  Maternal and Child Health
# 73971  Maternal and Child Health
# 74523  Maternal and Child Health
# 77118  Maternal and Child Health
# 78598  Maternal and Child Health
#
# [173 rows x 3 columns]

# %%
# create a key to narrow results so we can exclude data from 'Maternal and Child Health'
key = ehb_award_2023_df["HRSA Program Area Name"] == 'Maternal and Child Health'
nonmaternal_df = ehb_award_2023_df[~key] # exclude
maternal_df = ehb_award_2023_df[key] # include

# utilize key with 'keywords'
missed_stuff_df = nonmaternal_df[nonmaternal_df['Grant Program Name'].str.contains('Infant|Maternal|Fetus|Unborn|Pregnan|Breast', regex=True, case=False)]

missed_stuff_df
# Out:
#        Award Year  Financial Assistance                    Grantee Address  \
# 37969        2023              473618.0                   1010 N Kansas St
# 37974        2023              572024.0          600 Jefferson Ave Ste 100
# 37994        2023              587311.0                     1101 Church St
# 38189        2023               88216.0                1101 S Tennessee St
# 38272        2023              306973.0                301 Rose Admin BLDG
# ...           ...                   ...                                ...
# 46827        2023              598728.0           520 Lee Entrance STE 211
# 46834        2023              598879.0             3451 Walnut St RM 440A
# 46838        2023              599058.0                 201 Presidents Cir
# 46843        2023              599868.0                          6003 Tamu
# 46866        2023              578186.0  11060 Anderson St Bldg Magan Hall
#
#           Grantee City Grantee County Description Grantee County Name  \
# 37969          Wichita         County                        Sedgwick
# 37974          Memphis         County                          Shelby
# 37994         Waycross         County                            Ware
# 38189       Pine Bluff         County                       Jefferson
# 38272       Tuscaloosa                        NaN       Not Available
# ...                ...                        ...                 ...
# 46827          Amherst         County                            Erie
# 46834     Philadelphia         County                    Philadelphia
# 46838   Salt Lake City         County                       Salt Lake
# 46843  College Station         County                          Brazos
# 46866       Loma Linda         County                  San Bernardino
#
#                                             Grantee Name  Grantee Region Code  \
# 37969  UNIVERSITY OF KANSAS SCHOOL OF MEDICINE WICHIT...                  7.0
# 37974            METHODIST LE BONHEUR COMMUNITY OUTREACH                  4.0
# 37994               PUBLIC HEALTH, GEORGIA DEPARTMENT OF                  4.0
# 38189            JEFFERSON COMPREHENSIVE CARE SYSTEM INC                  6.0
# 38272                              University of Alabama                  NaN
# ...                                                  ...                  ...
# 46827  RESEARCH FOUNDATION FOR THE STATE UNIVERSITY O...                  2.0
# 46834    Trustees of the University of Pennsylvania, The                  3.0
# 46838                                 UNIVERSITY OF UTAH                  8.0
# 46843  TEXAS A & M UNIVERSITY SYSTEM HEALTH SCIENCE C...                  6.0
# 46866                              Loma Linda University                  9.0
#
#       HRSA Region Grantee State Abbreviation    State Name Grantee ZIP Code  \
# 37969    Region 7                         KS        Kansas       67214-3124
# 37974    Region 4                         TN     Tennessee       38105-4934
# 37994    Region 4                         GA       Georgia       31501-3525
# 38189    Region 6                         AR      Arkansas       71601-5801
# 38272         NaN                         AL       Alabama       35487-0001
# ...           ...                        ...           ...              ...
# 46827    Region 2                         NY      New York       14228-2577
# 46834    Region 3                         PA  Pennsylvania       19104-6205
# 46838    Region 8                         UT          Utah       84112-9049
# 46843    Region 6                         TX         Texas       77843-0001
# 46866    Region 9                         CA    California       92350-0001
#
#       Grant Activity Code Grant Number  Grant Serial Number  \
# 37969                 H12   H12HA24827                24827
# 37974                 H12   H12HA24874                24874
# 37994                 H12   H12HA24818                24818
# 38189                 H12   H12HA24773                24773
# 38272                 T34   T34HP42131                42131
# ...                   ...          ...                  ...
# 46827                 T34   T34HP42144                42144
# 46834                 T34   T34HP42132                42132
# 46838                 T34   T34HP42133                42133
# 46843                 T34   T34HP42127                42127
# 46866                 T34   T34HP42140                42140
#
#       Project Period Start Date Project Period Start Date Text String  \
# 37969                08/01/2012                            2012/08/01
# 37974                08/01/2012                            2012/08/01
# 37994                08/01/2012                            2012/08/01
# 38189                08/01/2012                            2012/08/01
# 38272                07/01/2021                            2021/07/01
# ...                         ...                                   ...
# 46827                07/01/2021                            2021/07/01
# 46834                07/01/2021                            2021/07/01
# 46838                07/01/2021                            2021/07/01
# 46843                07/01/2021                            2021/07/01
# 46866                07/01/2021                            2021/07/01
#
#       Grant Project Period End Date Grant Project Period End Date Text  \
# 37969                    07/31/2026                         2026/07/31
# 37974                    07/31/2026                         2026/07/31
# 37994                    07/31/2026                         2026/07/31
# 38189                    07/31/2026                         2026/07/31
# 38272                    06/30/2026                         2026/06/30
# ...                             ...                                ...
# 46827                    06/30/2026                         2026/06/30
# 46834                    06/30/2026                         2026/06/30
# 46838                    06/30/2026                         2026/06/30
# 46843                    06/30/2026                         2026/06/30
# 46866                    06/30/2026                         2026/06/30
#
#       HRSA Program Area Code HRSA Program Area Name   Complete County Name  \
# 37969                    HAB               HIV/AIDS        Sedgwick County
# 37974                    HAB               HIV/AIDS          Shelby County
# 37994                    HAB               HIV/AIDS            Ware County
# 38189                    HAB               HIV/AIDS       Jefferson County
# 38272                    BHW       Health Workforce                    NaN
# ...                      ...                    ...                    ...
# 46827                    BHW       Health Workforce            Erie County
# 46834                    BHW       Health Workforce    Philadelphia County
# 46838                    BHW       Health Workforce       Salt Lake County
# 46843                    BHW       Health Workforce          Brazos County
# 46866                    BHW       Health Workforce  San Bernardino County
#
#                                       Grant Program Name  \
# 37969  Ryan White Title IV Women, Infants, Children, ...
# 37974  Ryan White Title IV Women, Infants, Children, ...
# 37994  Ryan White Title IV Women, Infants, Children, ...
# 38189  Ryan White Title IV Women, Infants, Children, ...
# 38272  Primary Care Training and Enhancement-Communit...
# ...                                                  ...
# 46827  Primary Care Training and Enhancement-Communit...
# 46834  Primary Care Training and Enhancement-Communit...
# 46838  Primary Care Training and Enhancement-Communit...
# 46843  Primary Care Training and Enhancement-Communit...
# 46866  Primary Care Training and Enhancement-Communit...
#
#       Congressional District Name Congressional District Number  \
# 37969          Kansas District 04                           4.0
# 37974       Tennessee District 09                           9.0
# 37994         Georgia District 01                           1.0
# 38189        Arkansas District 04                           4.0
# 38272                     Unknown                           0.0
# ...                           ...                           ...
# 46827        New York District 26                          26.0
# 46834    Pennsylvania District 03                           3.0
# 46838            Utah District 01                           1.0
# 46843           Texas District 10                          10.0
# 46866      California District 23                          23.0
#
#       HHS Region Number U.S. Congressional Representative Name  \
# 37969               7.0                              Ron Estes
# 37974               4.0                            Steve Cohen
# 37994               4.0                 Earl L. “Buddy” Carter
# 38189               6.0                        Bruce Westerman
# 38272               NaN                                Unknown
# ...                 ...                                    ...
# 46827               2.0                          Brian Higgins
# 46834               3.0                           Dwight Evans
# 46838               8.0                         Blake D. Moore
# 46843               6.0                      Michael T. McCaul
# 46866               9.0                          Jay Obernolte
#
#       State and County Federal Information Processing Standard Code  \
# 37969                                            20173.0
# 37974                                            47157.0
# 37994                                            13299.0
# 38189                                             5069.0
# 38272                                                NaN
# ...                                                  ...
# 46827                                            36029.0
# 46834                                            42101.0
# 46838                                            49035.0
# 46843                                            48041.0
# 46866                                             6071.0
#
#       State FIPS Code U.S. - Mexico Border 100 Kilometer Indicator  \
# 37969              20                                            N
# 37974              47                                            N
# 37994              13                                            N
# 38189              05                                            N
# 38272              01                                            U
# ...               ...                                          ...
# 46827              36                                            N
# 46834              42                                            N
# 46838              49                                            N
# 46843              48                                            N
# 46866              06                                            N
#
#       U.S. - Mexico Border County Indicator Name of U.S. Senator Number One  \
# 37969                                     N                     Jerry Moran
# 37974                                     N                Marsha Blackburn
# 37994                                     N                      Jon Ossoff
# 38189                                     N                    John Boozman
# 38272                                   NaN                Tommy Tuberville
# ...                                     ...                             ...
# 46827                                     N              Charles E. Schumer
# 46834                                     N            Robert P. Casey, Jr.
# 46838                                     N                        Mike Lee
# 46843                                     N                     John Cornyn
# 46866                                     N                Dianne Feinstein
#
#       Name of U.S. Senator Number Two  \
# 37969                  Roger Marshall
# 37974                    Bill Hagerty
# 37994              Raphael G. Warnock
# 38189                      Tom Cotton
# 38272                Tommy Tuberville
# ...                               ...
# 46827           Kirsten E. Gillibrand
# 46834               Patrick J. Toomey
# 46838                     Mitt Romney
# 46843                       Ted Cruz
# 46866                    Alex Padilla
#
#            Uniform Data System Grant Program Description Abstract  \
# 37969  This notice announces the opportunity to apply...  No Link
# 37974  This notice announces the opportunity to apply...  No Link
# 37994  This notice announces the opportunity to apply...  No Link
# 38189  This notice announces the opportunity to apply...  No Link
# 38272  The purpose of this program is to train primar...  No Link
# ...                                                  ...      ...
# 46827  The purpose of this program is to train primar...  No Link
# 46834  The purpose of this program is to train primar...  No Link
# 46838  The purpose of this program is to train primar...  No Link
# 46843  The purpose of this program is to train primar...  No Link
# 46866  The purpose of this program is to train primar...  No Link
#
#                        Grantee Type Description DUNS Number  \
# 37969      Corporate Entity, Federal Tax Exempt   131621836
# 37974      Corporate Entity, Federal Tax Exempt   039804260
# 37994                    U.S. Government Entity   039487210
# 38189      Corporate Entity, Federal Tax Exempt   077391118
# 38272      Corporate Entity, Federal Tax Exempt   045632635
# ...                                         ...         ...
# 46827      Corporate Entity, Federal Tax Exempt   038633251
# 46834  Corporate Entity, Not Federal Tax Exempt   042250712
# 46838                    U.S. Government Entity   009095365
# 46843                    U.S. Government Entity   835607441
# 46866      Corporate Entity, Federal Tax Exempt   009656273
#
#       Unique Entity Identifier      CCN  \
# 37969             U49EMXEVWPB5      NaN
# 37974             MWXTN3VXGGH5      NaN
# 37994             JM4XCCPPE1P1      NaN
# 38189             YDFGKLZZ3MZ3  41821.0
# 38272             RCNJEHZ83EV6      NaN
# ...                        ...      ...
# 46827             LMCJKRFW5R81      NaN
# 46834             GM1XX56LEP58      NaN
# 46838             LL8GLEVH6MG3      NaN
# 46843             HFT7XTHB6563      NaN
# 46866             SZAKFNU35ZX5      NaN
#
#        Geocoding Artifact Address Primary X Coordinate  \
# 37969                                       -97.316143
# 37974                                       -90.040823
# 37994                                       -82.352987
# 38189                                       -91.998305
# 38272                                              NaN
# ...                                                ...
# 46827                                       -78.785538
# 46834                                       -75.194025
# 46838                                      -111.849403
# 46843                                       -96.354640
# 46866                                      -117.262758
#
#        Geocoding Artifact Address Primary Y Coordinate  \
# 37969                                        37.701526
# 37974                                        35.144182
# 37994                                        31.215988
# 38189                                        34.218942
# 38272                                              NaN
# ...                                                ...
# 46827                                        43.002054
# 46834                                        39.953088
# 46838                                        40.765020
# 46843                                        30.617880
# 46866                                        34.052423
#
#       Data Warehouse Record Create Date  \
# 37969                        10/13/2023
# 37974                        10/13/2023
# 37994                        10/13/2023
# 38189                        10/13/2023
# 38272                        10/13/2023
# ...                                 ...
# 46827                        10/13/2023
# 46834                        10/13/2023
# 46838                        10/13/2023
# 46843                        10/13/2023
# 46866                        10/13/2023
#
#       Data Warehouse Record Create Date Text  Unnamed: 43
# 37969                             2023/10/13          NaN
# 37974                             2023/10/13          NaN
# 37994                             2023/10/13          NaN
# 38189                             2023/10/13          NaN
# 38272                             2023/10/13          NaN
# ...                                      ...          ...
# 46827                             2023/10/13          NaN
# 46834                             2023/10/13          NaN
# 46838                             2023/10/13          NaN
# 46843                             2023/10/13          NaN
# 46866                             2023/10/13          NaN
#
# [179 rows x 44 columns]

# %%
# drop duplicate rows within 'Grant Program Name' to isolate unique 'Grant Activity Code' not contained within 'Maternal and Child Health'
missed_stuff_df = missed_stuff_df.drop_duplicates(subset = ('Grant Program Name'))

missed_stuff_df
# Out:
#        Award Year  Financial Assistance      Grantee Address  Grantee City  \
# 37969        2023              473618.0     1010 N Kansas St       Wichita
# 38272        2023              306973.0  301 Rose Admin BLDG    Tuscaloosa
# 41504        2023             1017620.0        4417 N 6th St  Philadelphia
#
#       Grantee County Description Grantee County Name  \
# 37969         County                        Sedgwick
# 38272                        NaN       Not Available
# 41504         County                    Philadelphia
#
#                                             Grantee Name  Grantee Region Code  \
# 37969  UNIVERSITY OF KANSAS SCHOOL OF MEDICINE WICHIT...                  7.0
# 38272                              University of Alabama                  NaN
# 41504                            ESPERANZA HEALTH CENTER                  3.0
#
#       HRSA Region Grantee State Abbreviation    State Name Grantee ZIP Code  \
# 37969    Region 7                         KS        Kansas       67214-3124
# 38272         NaN                         AL       Alabama       35487-0001
# 41504    Region 3                         PA  Pennsylvania       19140-2319
#
#       Grant Activity Code Grant Number  Grant Serial Number  \
# 37969                 H12   H12HA24827                24827
# 38272                 T34   T34HP42131                42131
# 41504                 Q8M   Q8MCS49113                49113
#
#       Project Period Start Date Project Period Start Date Text String  \
# 37969                08/01/2012                            2012/08/01
# 38272                07/01/2021                            2021/07/01
# 41504                06/01/2023                            2023/06/01
#
#       Grant Project Period End Date Grant Project Period End Date Text  \
# 37969                    07/31/2026                         2026/07/31
# 38272                    06/30/2026                         2026/06/30
# 41504                    05/31/2025                         2025/05/31
#
#       HRSA Program Area Code HRSA Program Area Name Complete County Name  \
# 37969                    HAB               HIV/AIDS      Sedgwick County
# 38272                    BHW       Health Workforce                  NaN
# 41504                   BPHC    Primary Health Care  Philadelphia County
#
#                                       Grant Program Name  \
# 37969  Ryan White Title IV Women, Infants, Children, ...
# 38272  Primary Care Training and Enhancement-Communit...
# 41504   Quality Improvement Fund – Maternal Health (Q8M)
#
#       Congressional District Name Congressional District Number  \
# 37969          Kansas District 04                           4.0
# 38272                     Unknown                           0.0
# 41504    Pennsylvania District 02                           2.0
#
#       HHS Region Number U.S. Congressional Representative Name  \
# 37969               7.0                              Ron Estes
# 38272               NaN                                Unknown
# 41504               3.0                       Brendan F. Boyle
#
#       State and County Federal Information Processing Standard Code  \
# 37969                                            20173.0
# 38272                                                NaN
# 41504                                            42101.0
#
#       State FIPS Code U.S. - Mexico Border 100 Kilometer Indicator  \
# 37969              20                                            N
# 38272              01                                            U
# 41504              42                                            N
#
#       U.S. - Mexico Border County Indicator Name of U.S. Senator Number One  \
# 37969                                     N                     Jerry Moran
# 38272                                   NaN                Tommy Tuberville
# 41504                                     N            Robert P. Casey, Jr.
#
#       Name of U.S. Senator Number Two  \
# 37969                  Roger Marshall
# 38272                Tommy Tuberville
# 41504               Patrick J. Toomey
#
#            Uniform Data System Grant Program Description Abstract  \
# 37969  This notice announces the opportunity to apply...  No Link
# 38272  The purpose of this program is to train primar...  No Link
# 41504  This notice announces the opportunity for curr...  No Link
#
#                    Grantee Type Description DUNS Number  \
# 37969  Corporate Entity, Federal Tax Exempt   131621836
# 38272  Corporate Entity, Federal Tax Exempt   045632635
# 41504  Corporate Entity, Federal Tax Exempt   825732159
#
#       Unique Entity Identifier       CCN  \
# 37969             U49EMXEVWPB5       NaN
# 38272             RCNJEHZ83EV6       NaN
# 41504             KLD1L3GC9NA5  391019.0
#
#        Geocoding Artifact Address Primary X Coordinate  \
# 37969                                       -97.316143
# 38272                                              NaN
# 41504                                       -75.136910
#
#        Geocoding Artifact Address Primary Y Coordinate  \
# 37969                                        37.701526
# 38272                                              NaN
# 41504                                        40.018984
#
#       Data Warehouse Record Create Date  \
# 37969                        10/13/2023
# 38272                        10/13/2023
# 41504                        10/13/2023
#
#       Data Warehouse Record Create Date Text  Unnamed: 43
# 37969                             2023/10/13          NaN
# 38272                             2023/10/13          NaN
# 41504                             2023/10/13          NaN

# %%
# create condensed df
missed_stuff_df = missed_stuff_df[['Grant Activity Code', 'Grant Program Name', 'HRSA Program Area Name']]

# widen columns in df to show the end of 'Grant Program Name'
pd.set_option('display.max_colwidth', None)

missed_stuff_df
# Out:
#       Grant Activity Code  \
# 37969                 H12
# 38272                 T34
# 41504                 Q8M
#
#                                                                                            Grant Program Name  \
# 37969  Ryan White Title IV Women, Infants, Children, Youth and  Affected Family Members AIDS Healthcare (H12)
# 38272                    Primary Care Training and Enhancement-Community Prevention and Maternal Health (T34)
# 41504                                                        Quality Improvement Fund – Maternal Health (Q8M)
#
#       HRSA Program Area Name
# 37969               HIV/AIDS
# 38272       Health Workforce
# 41504    Primary Health Care

# %%
# combine df using 'concat'
combined_award_codes = pd.concat([code_for_program_df, missed_stuff_df], ignore_index=True)

# widen columns in df to show the end of 'Grant Program Name'
pd.set_option('display.max_colwidth', None)

# drop null values
combined_award_codes.dropna()

combined_award_codes
# Out:
#     Grant Activity Code  \
# 0                   H84
# 1                   T73
# 2                   T20
# 3                   H47
# 4                   UJ2
# ..                  ...
# 171                 U42
# 172                 G23
# 173                 H12
# 174                 T34
# 175                 Q8M
#
#                                                                                          Grant Program Name  \
# 0                                                               Family Professional Partnership/CSHCN (H84)
# 1                   Leadership Education in Neurodevelopmental and Related Disorders Training Program (T73)
# 2                                                     Training CED/COR Pediatric and Child Psychiatry (T20)
# 3                                                           Children's Oral Healthcare Access Program (H47)
# 4                                                                MCH Autism Longitudinal Data Project (UJ2)
# ..                                                                                                      ...
# 171                                                      Integrated Community Service Systems /CSHCN  (U42)
# 172                                                       Healthy Start Leadership Training Institute (G23)
# 173  Ryan White Title IV Women, Infants, Children, Youth and  Affected Family Members AIDS Healthcare (H12)
# 174                    Primary Care Training and Enhancement-Community Prevention and Maternal Health (T34)
# 175                                                        Quality Improvement Fund – Maternal Health (Q8M)
#
#         HRSA Program Area Name
# 0    Maternal and Child Health
# 1    Maternal and Child Health
# 2    Maternal and Child Health
# 3    Maternal and Child Health
# 4    Maternal and Child Health
# ..                         ...
# 171  Maternal and Child Health
# 172  Maternal and Child Health
# 173                   HIV/AIDS
# 174           Health Workforce
# 175        Primary Health Care
#
# [176 rows x 3 columns]

# %%
# Slice off 'Grant Activity Code' form 'Grant Program Name'
###***** don't run this cell more than once, it will contiuouly slice 5 from the end of the string

combined_award_codes['Grant Program Name'] = combined_award_codes['Grant Program Name'].str.slice(0, -5)

combined_award_codes
# Out:
#     Grant Activity Code  \
# 0                   H84
# 1                   T73
# 2                   T20
# 3                   H47
# 4                   UJ2
# ..                  ...
# 171                 U42
# 172                 G23
# 173                 H12
# 174                 T34
# 175                 Q8M
#
#                                                                                     Grant Program Name  \
# 0                                                               Family Professional Partnership/CSHCN
# 1                   Leadership Education in Neurodevelopmental and Related Disorders Training Program
# 2                                                     Training CED/COR Pediatric and Child Psychiatry
# 3                                                           Children's Oral Healthcare Access Program
# 4                                                                MCH Autism Longitudinal Data Project
# ..                                                                                                 ...
# 171                                                      Integrated Community Service Systems /CSHCN
# 172                                                       Healthy Start Leadership Training Institute
# 173  Ryan White Title IV Women, Infants, Children, Youth and  Affected Family Members AIDS Healthcare
# 174                    Primary Care Training and Enhancement-Community Prevention and Maternal Health
# 175                                                        Quality Improvement Fund – Maternal Health
#
#         HRSA Program Area Name
# 0    Maternal and Child Health
# 1    Maternal and Child Health
# 2    Maternal and Child Health
# 3    Maternal and Child Health
# 4    Maternal and Child Health
# ..                         ...
# 171  Maternal and Child Health
# 172  Maternal and Child Health
# 173                   HIV/AIDS
# 174           Health Workforce
# 175        Primary Health Care
#
# [176 rows x 3 columns]

# %%
combined_award_codes = combined_award_codes.drop_duplicates(subset = ('Grant Program Name'))

# %%
# Number of unique grant programs
len(combined_award_codes['Grant Program Name'].unique())
# Out:
# 171

# %%
combined_award_codes
# Out:
#     Grant Activity Code  \
# 0                   H84
# 1                   T73
# 2                   T20
# 3                   H47
# 4                   UJ2
# ..                  ...
# 171                 U42
# 172                 G23
# 173                 H12
# 174                 T34
# 175                 Q8M
#
#                                                                                     Grant Program Name  \
# 0                                                               Family Professional Partnership/CSHCN
# 1                   Leadership Education in Neurodevelopmental and Related Disorders Training Program
# 2                                                     Training CED/COR Pediatric and Child Psychiatry
# 3                                                           Children's Oral Healthcare Access Program
# 4                                                                MCH Autism Longitudinal Data Project
# ..                                                                                                 ...
# 171                                                      Integrated Community Service Systems /CSHCN
# 172                                                       Healthy Start Leadership Training Institute
# 173  Ryan White Title IV Women, Infants, Children, Youth and  Affected Family Members AIDS Healthcare
# 174                    Primary Care Training and Enhancement-Community Prevention and Maternal Health
# 175                                                        Quality Improvement Fund – Maternal Health
#
#         HRSA Program Area Name
# 0    Maternal and Child Health
# 1    Maternal and Child Health
# 2    Maternal and Child Health
# 3    Maternal and Child Health
# 4    Maternal and Child Health
# ..                         ...
# 171  Maternal and Child Health
# 172  Maternal and Child Health
# 173                   HIV/AIDS
# 174           Health Workforce
# 175        Primary Health Care
#
# [171 rows x 3 columns]

# %%
# rename columns
combined_award_codes.rename(columns={'Grant Activity Code': 'Grant_Activity_Code ',
                                 'Grant Program Name': 'Grant_Program_Name',
                                 'HRSA Program Area Name': 'HRSA_Program_Area_Name'}, inplace=True)

combined_award_codes.head(2)
# Out:
#   Grant_Activity_Code   \
# 0                  H84
# 1                  T73
#
#                                                                    Grant_Program_Name  \
# 0                                              Family Professional Partnership/CSHCN
# 1  Leadership Education in Neurodevelopmental and Related Disorders Training Program
#
#       HRSA_Program_Area_Name
# 0  Maternal and Child Health
# 1  Maternal and Child Health

# %%
# export df to a csv file
combined_award_codes.to_csv('data/output/combined_award_program_codes.csv', index=False)
