# %%
import pandas as pd
from pathlib import Path
pd.set_option("display.max_columns", 200)

# %%
import csv
ehb_active_path = "EHB_ACTIVE_GRANT_FA_AGR.csv"
# https://data.hrsa.gov//DataDownload/DD_Files/EHB_ACTIVE_GRANT_FA_AGR.csv

# Read the modified Comic Books csv and store into Pandas DataFrame
ehb_active_df = pd.read_csv(ehb_active_path, encoding="utf-8", header=1)
# ehb_active_df.columns=ehb_active_df.iloc[0]
# ehb_active_df.head()
counts=0
with open(ehb_active_path,"r")as file:
    csv_reader=csv.reader(file)
    for row in csv_reader:
        if counts>1:
            print(row)
            count=1

# %%
ehb_active_df
# Out:
#        Award Year                      Grantee Name          Grantee Address  \
# 0            2022     ESPERANZA HEALTH CENTER, INC.            4417 N 6th St
# 1            2022         STAR COMMUNITY HEALTH INC  520 E Broad St, Ste 108
# 2            2022                  LEWIS UNIVERSITY        1 University Pkwy
# 3            2022  OUTER CAPE HEALTH SERVICES, INC.             710 Route 28
# 4            2022              RHODE ISLAND COLLEGE   600 Mount Pleasant Ave
# ...           ...                               ...                      ...
# 22722        2022        WESTCHESTER ELLENVILLE INC           10 Healthy Way
# 22723        2022                PHILADELPHIA FIGHT      1233 Locust St FL 5
# 22724        2022        BOARD OF REGENTS TENNESSEE       1 Bridgestone Park
# 22725        2022    THE UNIVERSITY OF SOUTH DAKOTA           414 E Clark St
# 22726        2022    TRUSTEES OF INDIANA UNIVERSITY        107 S Indiana Ave
#
# ...

# %%
ehb_active_df['HRSA Program Area Name'].value_counts()
# Out:
# HRSA Program Area Name
# Primary Health Care            7159
# Health Workforce               6385
# Maternal and Child Health      2885
# HIV/AIDS                       2676
# Rural Health                   1921
# Healthcare Systems             1434
# Office of the Administrator     267
# Name: count, dtype: int64

# %%
ehb_active_2013_df = ehb_active_df[(ehb_active_df['Award Year'] == 2023)]

key = ehb_active_2013_df["HRSA Program Area Name"]=='Maternal and Child Health'
nonmaternal_df = ehb_active_2013_df[~key]
maternal_df=ehb_active_2013_df[key]

# %%
missedstuff_df = nonmaternal_df[nonmaternal_df['Grant Program Name'].str.contains('Infant|Maternal|Fetus|Unborn|Pregnan|Breast', regex=True, case=False)]
missedstuff_df = missedstuff_df.drop_duplicates(subset=('Grant Program Name'))
missedstuff_df
# Out:
#       Award Year                      Grantee Name     Grantee Address  \
# 1823        2023        HOWARD BROWN HEALTH CENTER  4025 N Sheridan Rd
# 1861        2023  SUNSET PARK HEALTH COUNCIL, INC.         150 55th St
# 2046        2023                UNIVERSITY OF UTAH  201 Presidents Cir
#
#         Grantee City Grantee State Abbreviation Grantee ZIP Code  \
# 1823         Chicago                         IL       60613-2010
# 1861        Brooklyn                         NY       11220-2559
# 2046  Salt Lake City                         UT       84112-9049
#
#      Grant Activity Code Grant Number  Grant Serial Number  \
# 1823                 H12   H12HA24805                24805
# 1861                 Q8M   Q8MCS49133                49133
# 2046                 T34   T34HP42133                42133
#
#      Project Period Start Date Grant Project Period End Date  \
# 1823                2012/08/01                    2026/07/31
# ...

# %%
missedstuff_df = missedstuff_df.drop_duplicates(subset=('Grant Program Name'))
missedstuff_df
# Out:
#       Award Year                      Grantee Name     Grantee Address  \
# 1823        2023        HOWARD BROWN HEALTH CENTER  4025 N Sheridan Rd
# 1861        2023  SUNSET PARK HEALTH COUNCIL, INC.         150 55th St
# 2046        2023                UNIVERSITY OF UTAH  201 Presidents Cir
#
#         Grantee City Grantee State Abbreviation Grantee ZIP Code  \
# 1823         Chicago                         IL       60613-2010
# 1861        Brooklyn                         NY       11220-2559
# 2046  Salt Lake City                         UT       84112-9049
#
#      Grant Activity Code Grant Number  Grant Serial Number  \
# 1823                 H12   H12HA24805                24805
# 1861                 Q8M   Q8MCS49133                49133
# 2046                 T34   T34HP42133                42133
#
#      Project Period Start Date Grant Project Period End Date  \
# 1823                2012/08/01                    2026/07/31
# ...

# %%
ehb_active_2013_df['Grant Program Name'].unique()
# Out:
# array(['FY 2021 Ending the HIV Epidemic - Primary Care HIV Prevention (H8H)',
#        'Community Project Funding/Congressionally Directed Spending - Construction (CE1)',
#        'FY 2023 Bridge Access Program (H8L)',
#        'Maternal and Child Health Nutrition Training Program (T79)',
#        'Healthy Start Initiative-Eliminating Racial/Ethnic Disparities (H49)',
#        'Ryan White Part C Outpatient EIS Program (H76)',
#        'Health Center Program (H80)',
#        'Scholarships for Disadvantaged Students (T08)',
#        'MCHB State Systems Development Initiative (H18)',
#        'Ryan White Title IV Women, Infants, Children, Youth and  Affected Family Members AIDS Healthcare (H12)',
#        'Addiction Medicine Fellowship (T25)',
#        'FY 2023 Early Childhood Development (H8K)',
#        'Rural Residency Planning and Development Program (P13)',
#        'Nursing Workforce Diversity (D19)',
#        'Teaching Health Center Planning and Development Program (T9B)',
# ...

# %%
ehb_active_2013_df = ehb_active_df[(ehb_active_df['Grant Program Name'])].copy()
grantee_name=ehb_active_df.columns
grantee_name
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 ehb_active_2013_df = ehb_active_df[(ehb_active_df['Grant Program Name'])].copy()
#       2 grantee_name=ehb_active_df.columns
#       3 grantee_name
#
# File /opt/anaconda3/envs/pandas/lib/python3.12/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/anaconda3/envs/pandas/lib/python3.12/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
ehb_active_2013_df.drop('Unnamed: 29', axis= 1, inplace = True)
ehb_active_2013_df.drop('Grant Program Description', axis= 1, inplace = True)
ehb_active_2013_df.drop('Abstract', axis= 1, inplace = True)
ehb_active_2013_df.drop('Unique Entity Identifier', axis= 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 ehb_active_2013_df.drop('Unnamed: 29', axis= 1, inplace = True)
#       2 ehb_active_2013_df.drop('Grant Program Description', axis= 1, inplace = True)
#       3 ehb_active_2013_df.drop('Abstract', axis= 1, inplace = True)
#
# NameError: name 'ehb_active_2013_df' is not defined

# %%
ehb_active_2013_df.dropna(inplace = True)
ehb_active_clean = ehb_active_2013_df.copy()

# %%
ehb_active_clean.head(1)
# Number of unique grant programs
len(ehb_active_clean['Grant Program Name'].unique())
# Out:
# 72

# %%
# ehb_active_clean["HRSA Program Area Name"].unique()
temp = ehb_active_clean[(ehb_active_clean["HRSA Program Area Name"] == 'Rural Health')]
temp['Grant Program Name'].unique()
# Out:
# array(['Rural Residency Planning and Development Program (P13)',
#        'Rural Communities Opioid Response Program-Overdose Response (G39)',
#        'Rural Health Research Grant Program Cooperative Agreement (U1C)',
#        'Rural Health Network Development Planning Grant Program (P10)',
#        'Delta Health Systems Implementation Program (G38)',
#        'Radiation Exposure Screening and Education Program (H1G)',
#        'Rural Assistance Center for ORHP Cooperative Agreement (U56)',
#        'State Rural Health Coordination and Development (U14)'],
#       dtype=object)

# %%
ehb_active_clean[(ehb_active_clean["HRSA Program Area Name"] == 'Maternal and Child Health')]
# Out:
#       Award Year                                       Grantee Name  \
# 77          2023                                   CHICKASAW NATION
# 78          2023            Public Health, California Department of
# 118         2023             HEALTH, WASHINGTON STATE DEPARTMENT OF
# 191         2023  REGENTS OF THE UNIVERSITY OF CALIFORNIA, SAN F...
# 231         2023                                   EMORY UNIVERSITY
# ...          ...                                                ...
# 7428        2023                     AMERICAN ACADEMY OF PEDIATRICS
# 7874        2023  Health And Human Resources, West Virginia Depa...
# 7889        2023                    DEPARTMENT OF HEALTH NEW MEXICO
# 8485        2023                        UNIVERSITY OF SOUTH FLORIDA
# 8551        2023             HEALTH, WASHINGTON STATE DEPARTMENT OF
#
#               Grantee Address   Grantee City Grantee State Abbreviation  \
# 77           520 Arlington St            Ada                         OK
# ...

# %%
# Loop through each row in the CSV
    for row in csv_reader:
        # Check if the search term is in the row
        if search_term in row:
            print(f'Found "{search_term}" in row: {row}')
            found = True
            break  # Exit the loop if found

# If the word was not found, alert the user
if not found:
